# %%
import os
from dotenv import load_dotenv
load_dotenv(verbose=True, override=True)
# Out:
# True

# %%
os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_ENDPOINT"]=os.getenv("LANGCHAIN_ENDPOINT")
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
os.environ["LANGCHAIN_API_KEY"]
# Out:
# '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'

# %%
from langchain_openai import ChatOpenAI
LLM = ChatOpenAI(model="gpt-4o")
print(LLM)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x7fa318ea2da0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x7fa318ea3f70> root_client=<openai.OpenAI object at 0x7fa318ea31c0> root_async_client=<openai.AsyncOpenAI object at 0x7fa318ea3e80> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********')

# %%
## Input and get response form LLM
result = LLM.invoke("hello universe")
print(result)
# Out:
# content='Hello! How can I assist you today?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 9, 'total_tokens': 18, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': None, 'id': 'chatcmpl-BsGzg9V6Mff9eg21QwYSw8UoVLhwh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--aa152567-5f8b-49ee-b5aa-423a8050b1e5-0' usage_metadata={'input_tokens': 9, 'output_tokens': 9, 'total_tokens': 18, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|LLM

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='Langsmith is a suite of tools designed to enhance the development and deployment of applications powered by large language models (LLMs) and AI agents. Built by the team behind LangChain, Langsmith offers a range of functionalities aimed at improving the efficiency and effectiveness of AI-driven applications. Key features include:\n\n1. **Tracing and Debugging**: Langsmith provides tools for tracing the interactions and processes involved in applications using LLMs. This helps developers to debug and understand the behavior of their AI models more intuitively.\n\n2. **Evaluation**: The platform offers evaluation tools to assess the performance and output quality of language models. This is essential for ensuring that the models meet desired standards and function as expected in real-world scenarios.\n\n3. **Monitoring**: It includes capabilities for ongoing monitoring of deployed applications, helping to ensure consistent performance and to catch any anomalies or issues that might arise over time.\n\n4. **Deployment Support**: Langsmith facilitates smoother deployment processes by providing integrations and support that bridge the development and production environments.\n\nOverall, Langsmith is aimed at easing the complexities associated with building, testing, deploying, and maintaining AI applications that leverage advanced language models.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 234, 'prompt_tokens': 33, 'total_tokens': 267, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': None, 'id': 'chatcmpl-BsGuIICvxsaIqgvC6KTgsQMkbfKtO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--3a847dda-2b27-4e92-befa-0d9e171bff40-0' usage_metadata={'input_tokens': 33, 'output_tokens': 234, 'total_tokens': 267, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|LLM|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a tool designed to streamline the development, testing, and deployment of large language model (LLM) applications. It provides a suite of features that enable developers and engineers to more effectively handle the intricacies of working with LLMs. Key functionalities of Langsmith include integrated observability, testing, and evaluation tools that help users understand model behaviors and improve performance. It can also be used to refine prompt engineering and manage complex workflows by offering robust support for debugging and optimization processes within LLM applications. Langsmith is especially useful for those looking to enhance the reliability and efficiency of their LLM-driven solutions by providing a comprehensive platform for managing the lifecycle of such applications.
